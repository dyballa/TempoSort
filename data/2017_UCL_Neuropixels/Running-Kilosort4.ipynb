# %%
from kilosort import run_kilosort, DEFAULT_SETTINGS
# https://colab.research.google.com/github/mouseland/kilosort/blob/main/docs/tutorials/kilosort4.ipynb#scrollTo=MnOtna6Vlx8S

# %%
settings = DEFAULT_SETTINGS

settings['data_dir'] = '/Users/dyballa/repos/TempoSort/data/2017_UCL_Neuropixels/60s' # where the outputs files will be saved
settings['n_chan_bin'] = 385
settings['tmax'] = 5 # secs
settings['probe_path'] = 'forPRBimecP3opt3.mat'
ops, st, clu, tF, Wall, similar_templates, is_ref, est_contam_rate, kept_spikes = \
    run_kilosort(settings=settings, filename='/Users/dyballa/repos/TempoSort/data/2017_UCL_Neuropixels/60s/Hopkins_20160722_g0_t0.imec.ap_CAR.60sec.bin')
# Out:
# kilosort.run_kilosort: Kilosort version 4.0.20
# kilosort.run_kilosort: Python version 3.9.20
# kilosort.run_kilosort: ----------------------------------------
# kilosort.run_kilosort: System information:
# kilosort.run_kilosort: macOS-13.7-x86_64-i386-64bit x86_64
# kilosort.run_kilosort: i386
# kilosort.run_kilosort: Using CPU for PyTorch computations. Specify `device` to change this.
# kilosort.run_kilosort: ----------------------------------------
# kilosort.run_kilosort: Sorting /Users/dyballa/repos/TempoSort/data/2017_UCL_Neuropixels/60s/Hopkins_20160722_g0_t0.imec.ap_CAR.60sec.bin
# kilosort.run_kilosort: Interpreting binary file as default dtype='int16'. If data was saved in a different format, specify `data_dtype`.
# kilosort.run_kilosort:
# kilosort.run_kilosort: Computing preprocessing variables.
# kilosort.run_kilosort: ----------------------------------------
# kilosort.run_kilosort: Encountered error in `run_kilosort`:
# Traceback (most recent call last):
#   File "/Users/dyballa/miniconda3/envs/kilosort/lib/python3.9/site-packages/kilosort/run_kilosort.py", line 225, in run_kilosort
#     ops = compute_preprocessing(ops, device, tic0=tic0, file_object=file_object)
#   File "/Users/dyballa/miniconda3/envs/kilosort/lib/python3.9/site-packages/kilosort/run_kilosort.py", line 484, in compute_preprocessing
#     bfile = io.BinaryFiltered(ops['filename'], n_chan_bin, fs, NT, nt, twav_min,
#   File "/Users/dyballa/miniconda3/envs/kilosort/lib/python3.9/site-packages/kilosort/io.py", line 927, in __init__
#     super().__init__(filename, n_chan_bin, fs, NT, nt, nt0min, device,
#   File "/Users/dyballa/miniconda3/envs/kilosort/lib/python3.9/site-packages/kilosort/io.py", line 626, in __init__
#     total_samples = get_total_samples(filename, n_chan_bin, dtype)
#   File "/Users/dyballa/miniconda3/envs/kilosort/lib/python3.9/site-packages/kilosort/io.py", line 829, in get_total_samples
#     raise ValueError(
# ValueError: Bytes in binary file did not divide evenly, incorrect n_chan_bin ('number of channels' in GUI).
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 8
#       5 settings['tmax'] = 5
#       6 settings['probe_path'] = 'forPRBimecP3opt3.mat'
#       7 ops, st, clu, tF, Wall, similar_templates, is_ref, est_contam_rate, kept_spikes = \
# ----> 8     run_kilosort(settings=settings, filename='/Users/dyballa/repos/TempoSort/data/2017_UCL_Neuropixels/60s/Hopkins_20160722_g0_t0.imec.ap_CAR.60sec.bin')#, probe_name='/Users/dyballa/repos/TempoSort/data/2017_UCL_Neuropixels/forPRBimecP3opt3.mat')
#
# File ~/miniconda3/envs/kilosort/lib/python3.9/site-packages/kilosort/run_kilosort.py:225, in run_kilosort(settings, probe, probe_name, filename, data_dir, file_object, results_dir, data_dtype, do_CAR, invert_sign, device, progress_bar, save_extra_vars, clear_cache, save_preprocessed_copy, bad_channels, verbose_console)
#     222 logger.debug(f"Initial ops:\n{print_ops}\n")
#     224 # Set preprocessing and drift correction parameters
# --> 225 ops = compute_preprocessing(ops, device, tic0=tic0, file_object=file_object)
#     226 np.random.seed(1)
#     227 torch.cuda.manual_seed_all(1)
#
# File ~/miniconda3/envs/kilosort/lib/python3.9/site-packages/kilosort/run_kilosort.py:484, in compute_preprocessing(ops, device, tic0, file_object)
#     482 hp_filter = preprocessing.get_highpass_filter(fs, cutoff, device=device)
#     483 # Compute whitening matrix
# --> 484 bfile = io.BinaryFiltered(ops['filename'], n_chan_bin, fs, NT, nt, twav_min,
#     485                           chan_map, hp_filter, device=device, do_CAR=do_CAR,
#     486                           invert_sign=invert, dtype=dtype, tmin=tmin,
#     487                           tmax=tmax, artifact_threshold=artifact,
#     488                           shift=shift, scale=scale, file_object=file_object)
#     490 logger.info(f'N samples: {bfile.n_samples}')
#     491 logger.info(f'N seconds: {bfile.n_samples/fs}')
#
# File ~/miniconda3/envs/kilosort/lib/python3.9/site-packages/kilosort/io.py:927, in BinaryFiltered.__init__(self, filename, n_chan_bin, fs, NT, nt, nt0min, chan_map, hp_filter, whiten_mat, dshift, device, do_CAR, artifact_threshold, invert_sign, dtype, tmin, tmax, shift, scale, file_object)
#     918 def __init__(self, filename: str, n_chan_bin: int, fs: int = 30000,
#     919              NT: int = 60000, nt: int = 61, nt0min: int = 20,
#     920              chan_map: np.ndarray = None, hp_filter: torch.Tensor = None,
#    (...)
#     924              dtype=None, tmin: float = 0.0, tmax: float = np.inf,
#     925              shift=None, scale=None, file_object=None):
# --> 927     super().__init__(filename, n_chan_bin, fs, NT, nt, nt0min, device,
#     928                      dtype=dtype, tmin=tmin, tmax=tmax, shift=shift,
#     929                      scale=scale, file_object=file_object)
#     930     self.chan_map = chan_map
#     931     self.whiten_mat = whiten_mat
#
# File ~/miniconda3/envs/kilosort/lib/python3.9/site-packages/kilosort/io.py:626, in BinaryRWFile.__init__(self, filename, n_chan_bin, fs, NT, nt, nt0min, device, write, dtype, tmin, tmax, shift, scale, file_object)
#     624 # Must come after dtype since dtype is necessary for nbytesread
#     625 if file_object is None:
# --> 626     total_samples = get_total_samples(filename, n_chan_bin, dtype)
#     627 else:
#     628     n, c = file_object.shape
#
# File ~/miniconda3/envs/kilosort/lib/python3.9/site-packages/kilosort/io.py:829, in get_total_samples(filename, n_channels, dtype)
#     826 samples = (total_bytes / bytes_per_sample)
#     828 if samples%1 != 0:
# --> 829     raise ValueError(
#     830         "Bytes in binary file did not divide evenly, "
#     831         "incorrect n_chan_bin ('number of channels' in GUI)."
#     832     )
#     833 else:
#     834     return int(samples)
#
# ValueError: Bytes in binary file did not divide evenly, incorrect n_chan_bin ('number of channels' in GUI).

# %%
import numpy as np
import pandas as pd
from pathlib import Path

# outputs saved to results_dir
results_dir = Path(settings['data_dir']).joinpath('kilosort4')
ops = np.load(results_dir / 'ops.npy', allow_pickle=True).item()
camps = pd.read_csv(results_dir / 'cluster_Amplitude.tsv', sep='\t')['Amplitude'].values
contam_pct = pd.read_csv(results_dir / 'cluster_ContamPct.tsv', sep='\t')['ContamPct'].values
chan_map =  np.load(results_dir / 'channel_map.npy')
templates =  np.load(results_dir / 'templates.npy')
chan_best = (templates**2).sum(axis=1).argmax(axis=-1)
chan_best = chan_map[chan_best]
amplitudes = np.load(results_dir / 'amplitudes.npy')
st = np.load(results_dir / 'spike_times.npy')
clu = np.load(results_dir / 'spike_clusters.npy')
firing_rates = np.unique(clu, return_counts=True)[1] * 30000 / st.max()
dshift = ops['dshift']

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from matplotlib import gridspec, rcParams
rcParams['axes.spines.top'] = False
rcParams['axes.spines.right'] = False
gray = .5 * np.ones(3)

fig = plt.figure(figsize=(10,10), dpi=100)
grid = gridspec.GridSpec(3, 3, figure=fig, hspace=0.5, wspace=0.5)

ax = fig.add_subplot(grid[0,0])
ax.plot(np.arange(0, ops['Nbatches'])*2, dshift);
ax.set_xlabel('time (sec.)')
ax.set_ylabel('drift (um)')

ax = fig.add_subplot(grid[0,1:])
t0 = 0
t1 = np.nonzero(st > ops['fs']*4.9)[0][0]
ax.scatter(st[t0:t1]/30000., chan_best[clu[t0:t1]], s=0.5, color='k', alpha=0.25)
ax.set_xlim([0, 5])
ax.set_ylim([chan_map.max(), 0])
ax.set_xlabel('time (sec.)')
ax.set_ylabel('channel')
ax.set_title('spikes from units')

ax = fig.add_subplot(grid[1,0])
nb=ax.hist(firing_rates, 20, color=gray)
ax.set_xlabel('firing rate (Hz)')
ax.set_ylabel('# of units')

ax = fig.add_subplot(grid[1,1])
nb=ax.hist(camps, 20, color=gray)
ax.set_xlabel('amplitude')
ax.set_ylabel('# of units')

ax = fig.add_subplot(grid[1,2])
nb=ax.hist(np.minimum(100, contam_pct), np.arange(0,105,5), color=gray)
ax.plot([10, 10], [0, nb[0].max()], 'k--')
ax.set_xlabel('% contamination')
ax.set_ylabel('# of units')
ax.set_title('< 10% = good units')

for k in range(2):
    ax = fig.add_subplot(grid[2,k])
    is_ref = contam_pct<10.
    ax.scatter(firing_rates[~is_ref], camps[~is_ref], s=3, color='r', label='mua', alpha=0.25)
    ax.scatter(firing_rates[is_ref], camps[is_ref], s=3, color='b', label='good', alpha=0.25)
    ax.set_ylabel('amplitude (a.u.)')
    ax.set_xlabel('firing rate (Hz)')
    ax.legend()
    if k==1:
        ax.set_xscale('log')
        ax.set_yscale('log')
        ax.set_title('loglog')
