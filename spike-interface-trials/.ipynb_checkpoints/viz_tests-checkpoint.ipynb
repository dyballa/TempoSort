# %%
# !pip install kachery_cloud spikeforest
# !pip install "spikeinterface==0.99.1"
# !pip install matplotlib ipympl ipywidgets
# !pip install hdbscan
# !pip install numba
# !pip install spiketoolkit
# Out:
# Requirement already satisfied: kachery_cloud in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (0.4.9)
# Requirement already satisfied: spikeforest in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (0.12.7)
# Requirement already satisfied: requests in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (from kachery_cloud) (2.32.3)
# Requirement already satisfied: click in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (from kachery_cloud) (8.1.7)
# Requirement already satisfied: simplejson in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (from kachery_cloud) (3.19.3)
# Requirement already satisfied: cryptography in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (from kachery_cloud) (43.0.0)
# Requirement already satisfied: pubnub>=7.2.0 in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (from kachery_cloud) (8.1.0)
# Requirement already satisfied: dask[distributed] in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (from kachery_cloud) (2024.8.0)
# Requirement already satisfied: kachery-client>=1.2.0 in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (from spikeforest) (1.2.0)
# Requirement already satisfied: sortingview>=0.7.3 in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (from spikeforest) (0.13.5)
# Requirement already satisfied: spikeinterface>=0.93.0 in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (from spikeforest) (0.99.1)
# Requirement already satisfied: jinjaroot in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (from kachery-client>=1.2.0->spikeforest) (0.0.6)
# Requirement already satisfied: pycryptodomex>=3.3 in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (from pubnub>=7.2.0->kachery_cloud) (3.20.0)
# Requirement already satisfied: cbor2 in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (from pubnub>=7.2.0->kachery_cloud) (5.6.4)
# Requirement already satisfied: aiohttp in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (from pubnub>=7.2.0->kachery_cloud) (3.10.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (from requests->kachery_cloud) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (from requests->kachery_cloud) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (from requests->kachery_cloud) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (from requests->kachery_cloud) (2024.7.4)
# Requirement already satisfied: figurl>=0.2.22 in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (from sortingview>=0.7.3->spikeforest) (0.2.22)
# Requirement already satisfied: matplotlib in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (from sortingview>=0.7.3->spikeforest) (3.9.2)
# Requirement already satisfied: pynwb in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (from sortingview>=0.7.3->spikeforest) (2.8.1)
# Requirement already satisfied: pyyaml in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (from sortingview>=0.7.3->spikeforest) (6.0.2)
# Requirement already satisfied: h5py in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (from sortingview>=0.7.3->spikeforest) (3.11.0)
# Requirement already satisfied: numpy in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (from spikeinterface>=0.93.0->spikeforest) (1.26.4)
# Requirement already satisfied: neo>=0.12.0 in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (from spikeinterface>=0.93.0->spikeforest) (0.14.0.dev0)
# Requirement already satisfied: joblib in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (from spikeinterface>=0.93.0->spikeforest) (1.4.2)
# Requirement already satisfied: threadpoolctl in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (from spikeinterface>=0.93.0->spikeforest) (3.5.0)
# Requirement already satisfied: tqdm in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (from spikeinterface>=0.93.0->spikeforest) (4.66.5)
# Requirement already satisfied: probeinterface>=0.2.19 in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (from spikeinterface>=0.93.0->spikeforest) (0.2.24)
# Requirement already satisfied: cffi>=1.12 in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (from cryptography->kachery_cloud) (1.17.0)
# Requirement already satisfied: cloudpickle>=1.5.0 in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (from dask[distributed]->kachery_cloud) (3.0.0)
# Requirement already satisfied: fsspec>=2021.09.0 in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (from dask[distributed]->kachery_cloud) (2024.6.1)
# Requirement already satisfied: packaging>=20.0 in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (from dask[distributed]->kachery_cloud) (24.1)
# Requirement already satisfied: partd>=1.4.0 in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (from dask[distributed]->kachery_cloud) (1.4.2)
# Requirement already satisfied: toolz>=0.10.0 in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (from dask[distributed]->kachery_cloud) (0.12.1)
# Requirement already satisfied: importlib-metadata>=4.13.0 in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (from dask[distributed]->kachery_cloud) (8.4.0)
# Requirement already satisfied: distributed==2024.8.0 in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (from dask[distributed]->kachery_cloud) (2024.8.0)
# Requirement already satisfied: jinja2>=2.10.3 in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (from distributed==2024.8.0->dask[distributed]->kachery_cloud) (3.1.4)
# Requirement already satisfied: locket>=1.0.0 in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (from distributed==2024.8.0->dask[distributed]->kachery_cloud) (1.0.0)
# Requirement already satisfied: msgpack>=1.0.0 in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (from distributed==2024.8.0->dask[distributed]->kachery_cloud) (1.0.8)
# Requirement already satisfied: psutil>=5.7.2 in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (from distributed==2024.8.0->dask[distributed]->kachery_cloud) (6.0.0)
# Requirement already satisfied: sortedcontainers>=2.0.5 in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (from distributed==2024.8.0->dask[distributed]->kachery_cloud) (2.4.0)
# Requirement already satisfied: tblib>=1.6.0 in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (from distributed==2024.8.0->dask[distributed]->kachery_cloud) (3.0.0)
# Requirement already satisfied: tornado>=6.0.4 in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (from distributed==2024.8.0->dask[distributed]->kachery_cloud) (6.4.1)
# Requirement already satisfied: zict>=3.0.0 in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (from distributed==2024.8.0->dask[distributed]->kachery_cloud) (3.0.0)
# Requirement already satisfied: pycparser in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (from cffi>=1.12->cryptography->kachery_cloud) (2.22)
# Requirement already satisfied: altair in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (from figurl>=0.2.22->sortingview>=0.7.3->spikeforest) (5.4.1)
# Requirement already satisfied: zipp>=0.5 in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (from importlib-metadata>=4.13.0->dask[distributed]->kachery_cloud) (3.20.1)
# Requirement already satisfied: quantities>=0.14.1 in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (from neo>=0.12.0->spikeinterface>=0.93.0->spikeforest) (0.16.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (from aiohttp->pubnub>=7.2.0->kachery_cloud) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (from aiohttp->pubnub>=7.2.0->kachery_cloud) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (from aiohttp->pubnub>=7.2.0->kachery_cloud) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (from aiohttp->pubnub>=7.2.0->kachery_cloud) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (from aiohttp->pubnub>=7.2.0->kachery_cloud) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (from aiohttp->pubnub>=7.2.0->kachery_cloud) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (from aiohttp->pubnub>=7.2.0->kachery_cloud) (4.0.3)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (from matplotlib->sortingview>=0.7.3->spikeforest) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (from matplotlib->sortingview>=0.7.3->spikeforest) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (from matplotlib->sortingview>=0.7.3->spikeforest) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (from matplotlib->sortingview>=0.7.3->spikeforest) (1.4.5)
# Requirement already satisfied: pillow>=8 in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (from matplotlib->sortingview>=0.7.3->spikeforest) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (from matplotlib->sortingview>=0.7.3->spikeforest) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (from matplotlib->sortingview>=0.7.3->spikeforest) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (from matplotlib->sortingview>=0.7.3->spikeforest) (6.4.4)
# Requirement already satisfied: hdmf>=3.14.0 in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (from pynwb->sortingview>=0.7.3->spikeforest) (3.14.3)
# Requirement already satisfied: pandas>=1.1.5 in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (from pynwb->sortingview>=0.7.3->spikeforest) (2.2.2)
# Requirement already satisfied: jsonschema>=2.6.0 in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (from hdmf>=3.14.0->pynwb->sortingview>=0.7.3->spikeforest) (4.23.0)
# Requirement already satisfied: ruamel-yaml>=0.16 in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (from hdmf>=3.14.0->pynwb->sortingview>=0.7.3->spikeforest) (0.18.6)
# Requirement already satisfied: scipy>=1.4 in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (from hdmf>=3.14.0->pynwb->sortingview>=0.7.3->spikeforest) (1.13.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (from jinja2>=2.10.3->distributed==2024.8.0->dask[distributed]->kachery_cloud) (2.1.5)
# Requirement already satisfied: pytz>=2020.1 in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (from pandas>=1.1.5->pynwb->sortingview>=0.7.3->spikeforest) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (from pandas>=1.1.5->pynwb->sortingview>=0.7.3->spikeforest) (2024.1)
# Requirement already satisfied: six>=1.5 in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib->sortingview>=0.7.3->spikeforest) (1.16.0)
# Requirement already satisfied: narwhals>=1.5.2 in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (from altair->figurl>=0.2.22->sortingview>=0.7.3->spikeforest) (1.5.5)
# Requirement already satisfied: typing-extensions>=4.10.0 in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (from altair->figurl>=0.2.22->sortingview>=0.7.3->spikeforest) (4.12.2)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (from jsonschema>=2.6.0->hdmf>=3.14.0->pynwb->sortingview>=0.7.3->spikeforest) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (from jsonschema>=2.6.0->hdmf>=3.14.0->pynwb->sortingview>=0.7.3->spikeforest) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (from jsonschema>=2.6.0->hdmf>=3.14.0->pynwb->sortingview>=0.7.3->spikeforest) (0.20.0)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.7 in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (from ruamel-yaml>=0.16->hdmf>=3.14.0->pynwb->sortingview>=0.7.3->spikeforest) (0.2.8)
# Requirement already satisfied: spikeinterface==0.99.1 in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (0.99.1)
# Requirement already satisfied: numpy in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (from spikeinterface==0.99.1) (1.26.4)
# Requirement already satisfied: neo>=0.12.0 in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (from spikeinterface==0.99.1) (0.14.0.dev0)
# Requirement already satisfied: joblib in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (from spikeinterface==0.99.1) (1.4.2)
# Requirement already satisfied: threadpoolctl in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (from spikeinterface==0.99.1) (3.5.0)
# Requirement already satisfied: tqdm in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (from spikeinterface==0.99.1) (4.66.5)
# Requirement already satisfied: probeinterface>=0.2.19 in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (from spikeinterface==0.99.1) (0.2.24)
# Requirement already satisfied: packaging in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (from neo>=0.12.0->spikeinterface==0.99.1) (24.1)
# Requirement already satisfied: quantities>=0.14.1 in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (from neo>=0.12.0->spikeinterface==0.99.1) (0.16.0)
# Requirement already satisfied: matplotlib in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (3.9.2)
# Requirement already satisfied: ipympl in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (0.9.4)
# Requirement already satisfied: ipywidgets in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (8.1.5)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (from matplotlib) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy>=1.23 in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (from matplotlib) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (from matplotlib) (6.4.4)
# Requirement already satisfied: ipython-genutils in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (from ipympl) (0.2.0)
# Requirement already satisfied: ipython<9 in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (from ipympl) (8.18.1)
# Requirement already satisfied: traitlets<6 in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (from ipympl) (5.14.3)
# Requirement already satisfied: comm>=0.1.3 in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (from ipywidgets) (0.2.2)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (from ipywidgets) (4.0.13)
# Requirement already satisfied: jupyterlab-widgets~=3.0.12 in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (from ipywidgets) (3.0.13)
# Requirement already satisfied: zipp>=3.1.0 in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib) (3.20.1)
# Requirement already satisfied: decorator in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (from ipython<9->ipympl) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (from ipython<9->ipympl) (0.19.1)
# Requirement already satisfied: matplotlib-inline in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (from ipython<9->ipympl) (0.1.7)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (from ipython<9->ipympl) (3.0.47)
# Requirement already satisfied: pygments>=2.4.0 in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (from ipython<9->ipympl) (2.18.0)
# Requirement already satisfied: stack-data in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (from ipython<9->ipympl) (0.6.3)
# Requirement already satisfied: typing-extensions in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (from ipython<9->ipympl) (4.12.2)
# Requirement already satisfied: exceptiongroup in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (from ipython<9->ipympl) (1.2.2)
# Requirement already satisfied: pexpect>4.3 in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (from ipython<9->ipympl) (4.9.0)
# Requirement already satisfied: six>=1.5 in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (from jedi>=0.16->ipython<9->ipympl) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (from pexpect>4.3->ipython<9->ipympl) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython<9->ipympl) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (from stack-data->ipython<9->ipympl) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (from stack-data->ipython<9->ipympl) (2.4.1)
# Requirement already satisfied: pure-eval in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (from stack-data->ipython<9->ipympl) (0.2.3)
# Requirement already satisfied: hdbscan in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (0.8.38.post1)
# Requirement already satisfied: numpy<3,>=1.20 in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (from hdbscan) (1.26.4)
# Requirement already satisfied: scipy>=1.0 in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (from hdbscan) (1.13.1)
# Requirement already satisfied: scikit-learn>=0.20 in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (from hdbscan) (1.5.1)
# Requirement already satisfied: joblib>=1.0 in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (from hdbscan) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (from scikit-learn>=0.20->hdbscan) (3.5.0)
# Requirement already satisfied: numba in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (0.60.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (from numba) (0.43.0)
# Requirement already satisfied: numpy<2.1,>=1.22 in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (from numba) (1.26.4)
# Requirement already satisfied: spiketoolkit in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (0.7.7)
# Requirement already satisfied: numpy in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (from spiketoolkit) (1.26.4)
# Requirement already satisfied: spikeextractors>=0.9.7 in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (from spiketoolkit) (0.9.11)
# Requirement already satisfied: spikemetrics>=0.2.4 in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (from spiketoolkit) (0.2.4)
# Requirement already satisfied: spikefeatures in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (from spiketoolkit) (0.1.2)
# Requirement already satisfied: scikit-learn in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (from spiketoolkit) (1.5.1)
# Requirement already satisfied: scipy in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (from spiketoolkit) (1.13.1)
# Requirement already satisfied: pandas in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (from spiketoolkit) (2.2.2)
# Requirement already satisfied: networkx in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (from spiketoolkit) (3.2.1)
# Requirement already satisfied: joblib in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (from spiketoolkit) (1.4.2)
# Requirement already satisfied: tqdm in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (from spikeextractors>=0.9.7->spiketoolkit) (4.66.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (from pandas->spiketoolkit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (from pandas->spiketoolkit) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (from pandas->spiketoolkit) (2024.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (from scikit-learn->spiketoolkit) (3.5.0)
# Requirement already satisfied: six>=1.5 in /Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas->spiketoolkit) (1.16.0)

# %%
# %matplotlib widget

# %%
import numpy
#Assorted useful python packages
import os
import numpy as np
import tqdm as notebook
import matplotlib.pyplot as plt
from pprint import pprint
import json

import spikeinterface.full as si #all spikeinterface modules
import spikeinterface.extractors as se
import spiketoolkit as st
import kachery_cloud as kcl #cloud host for spikeforest datasets
import spikeforest as sf #forked version of spikeforest

# %%
current_dir = os.getcwd()

#Choose dataset
first_boyden_recording_sf = sf.load_spikeforest_recording(study_name='paired_boyden32c', recording_name='1103_1_1') #, uri='sha1://849e53560c9241c1206a82cfb8718880fc1c6038?paired-boyden-spikeforest-recordings.json')
first_boyden_sorting_sf = sf.load_spikeforest_sorting_output(study_name='paired_boyden32c', recording_name='1103_1_1', sorter_name='JRClust')

#Convert dataset to spikeinterface format
first_boyden_recording = first_boyden_recording_sf.get_recording_extractor()
first_boyden_sorting = first_boyden_sorting_sf.get_sorting_extractor()

print(f'{first_boyden_recording_sf.study_set_name}/{first_boyden_recording_sf.study_name}/{first_boyden_recording_sf.recording_name}')
print(f'{first_boyden_sorting_sf.study_name}/{first_boyden_sorting_sf.recording_name}/{first_boyden_sorting_sf.sorter_name}')

##Set output folder
output_folder_MS = os.path.join(current_dir, 'folder_MS_5')
# Out:
# PAIRED_BOYDEN/paired_boyden32c/1103_1_1
# paired_boyden32c/1103_1_1/JRClust

# %%
# ## Apply filters
# recording_bp = st.preprocessing.bandpass_filter(first_boyden_recording, freq_min=300, freq_max=6000)
# recording_notch = st.preprocessing.notch_filter(first_boyden_recording, freq=1000, q=10)

# %%
# test_sorting = si.run_sorter(sorter_name='spykingcircus2', recording=first_boyden_recording, remove_existing_folder=True, output_folder=output_folder_MS)

# %%
import scipy.signal as signal

def bandpass_filter_data(data, freq_min, freq_max, sample_rate, order=4):
    nyquist = 0.5 * sample_rate
    low = freq_min / nyquist
    high = freq_max / nyquist
    b, a = signal.butter(order, [low, high], btype='band')
    filtered_data = signal.filtfilt(b, a, data, axis=0)
    return filtered_data

# Example for filtering data manually
sample_rate = first_boyden_recording.get_sampling_frequency()
raw_data = first_boyden_recording.get_traces()
filtered_data = bandpass_filter_data(raw_data, freq_min=300, freq_max=6000, sample_rate=sample_rate)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[9], line 14
#      12 sample_rate = first_boyden_recording.get_sampling_frequency()
#      13 # raw_data = first_boyden_recording.get_traces()
# ---> 14 filtered_data = bandpass_filter_data(first_boyden_recording, freq_min=300, freq_max=6000, sample_rate=sample_rate)
#
# Cell In[9], line 8, in bandpass_filter_data(data, freq_min, freq_max, sample_rate, order)
#       6 high = freq_max / nyquist
#       7 b, a = signal.butter(order, [low, high], btype='band')
# ----> 8 filtered_data = signal.filtfilt(b, a, data, axis=0)
#       9 return filtered_data
#
# File ~/miniconda3/envs/spikesort/lib/python3.9/site-packages/scipy/signal/_signaltools.py:4171, in filtfilt(b, a, x, axis, padtype, padlen, method, irlen)
#    4168     return y
#    4170 # method == "pad"
# -> 4171 edge, ext = _validate_pad(padtype, padlen, x, axis,
#    4172                           ntaps=max(len(a), len(b)))
#    4174 # Get the steady state of the filter's step response.
#    4175 zi = lfilter_zi(b, a)
#
# File ~/miniconda3/envs/spikesort/lib/python3.9/site-packages/scipy/signal/_signaltools.py:4220, in _validate_pad(padtype, padlen, x, axis, ntaps)
#    4217     edge = padlen
#    4219 # x's 'axis' dimension must be bigger than edge.
# -> 4220 if x.shape[axis] <= edge:
#    4221     raise ValueError("The length of the input vector x must be greater "
#    4222                      "than padlen, which is %d." % edge)
#    4224 if padtype is not None and edge > 0:
#    4225     # Make an extension of length `edge` at each
#    4226     # end of the input array.
#
# IndexError: tuple index out of range

# %%
#matplotlib backend
si.set_default_plotter_backend(backend="ipywidgets")
print(si.get_default_plotter_backend())

from spikeinterface.preprocessing import common_reference

# ipywidgets backend also supports multiple "layers" for plot_traces
recording = first_boyden_recording
rec_dict = dict(filt=recording, cmr=common_reference(recording))
w = si.plot_traces(recording=rec_dict, backend="ipywidgets")
# w = si.plot_spikes_on_traces(recording=rec_dict, backend="ipywidgets")
# w = si.plot_spikes_on_traces(test_sorting, backend="ipywidgets")
# Out:
# ipywidgets
# AppLayout(children=(TimeSlider(children=(Dropdown(description='segment', options=(0,), value=0), Button(icon='…

# %%
import spikeinterface as si
import spiketoolkit as st
import spikeforest as sf
import numpy as np
import scipy.signal as signal
import matplotlib.pyplot as plt
from spikeinterface.core import BaseRecording
from spikeinterface.preprocessing import common_reference
import spikeinterface.plotting as spk_plot

# Load the recording from SpikeForest
first_boyden_recording_sf = sf.load_spikeforest_recording(study_name='paired_boyden32c', recording_name='1103_1_1')
first_boyden_recording = first_boyden_recording_sf.get_recording_extractor()

# Bandpass filter function
def bandpass_filter_data(data, freq_min, freq_max, sample_rate, order=4):
    nyquist = 0.5 * sample_rate
    low = freq_min / nyquist
    high = freq_max / nyquist
    b, a = signal.butter(order, [low, high], btype='band')
    filtered_data = signal.filtfilt(b, a, data, axis=0)
    return filtered_data

# Apply the bandpass filter to the raw data
sample_rate = first_boyden_recording.get_sampling_frequency()
raw_data = first_boyden_recording.get_traces()
filtered_data = bandpass_filter_data(raw_data, freq_min=300, freq_max=6000, sample_rate=sample_rate)

# Custom RecordingExtractor class to handle filtered data
class CustomRecordingExtractor(BaseRecordingExtractor):
    def __init__(self, data, sampling_frequency, channel_names=None):
        super().__init__()
        self._data = data
        self._sampling_frequency = sampling_frequency
        self._n_channels, self._n_samples = data.shape
        self._channel_ids = np.arange(self._n_channels)
        self._channel_names = channel_names if channel_names is not None else [f'Channel {i}' for i in self._channel_ids]

    def get_num_channels(self):
        return self._n_channels

    def get_num_frames(self):
        return self._n_samples

    def get_traces(self, start_frame=0, end_frame=None, channel_ids=None):
        if end_frame is None:
            end_frame = self._n_samples
        if channel_ids is None:
            channel_ids = self._channel_ids
        return self._data[channel_ids, start_frame:end_frame]

    def get_channel_ids(self):
        return self._channel_ids

    def get_channel_names(self):
        return self._channel_names

    def get_sampling_frequency(self):
        return self._sampling_frequency

# Wrap the filtered data into the custom extractor
channel_names = [f'Channel {i}' for i in range(filtered_data.shape[0])]
custom_recording = CustomRecordingExtractor(filtered_data, sampling_frequency, channel_names)

# Verify the type of the custom recording
print("Custom recording type:", type(custom_recording))

# Visualization using SpikeInterface's built-in plotting functions
si.set_default_plotter_backend(backend="ipywidgets")
print("Using backend:", si.get_default_plotter_backend())

# Create a dictionary with the filtered recording
rec_dict = dict(filt=custom_recording, cmr=common_reference(custom_recording))

# # Plot traces with SpikeInterface's plotting functions
# w = spk_plot.plot_traces(recording=rec_dict, backend="ipywidgets")

# # Optional: For manual plotting using matplotlib
# def plot_filtered_data(recording):
#     num_channels = recording.get_num_channels()
#     data = recording.get_traces()

#     plt.figure(figsize=(12, 6))
#     for i in range(min(10, num_channels)):  # Plot the first 10 channels or fewer if fewer channels are present
#         plt.plot(data[i, :], label=f'Channel {i}')

#     plt.title('Filtered Traces')
#     plt.xlabel('Sample Index')
#     plt.ylabel('Amplitude')
#     plt.legend()
#     plt.show()

# # Plot using matplotlib
# plot_filtered_data(custom_recording)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[11], line 7
#       5 import scipy.signal as signal
#       6 import matplotlib.pyplot as plt
# ----> 7 from spikeinterface.core import BaseRecordingExtractor
#       8 from spikeinterface.preprocessing import common_reference
#       9 import spikeinterface.plotting as spk_plot
#
# ImportError: cannot import name 'BaseRecordingExtractor' from 'spikeinterface.core' (/Users/abdulrahman.mahmoud/miniconda3/envs/spikesort/lib/python3.9/site-packages/spikeinterface/core/__init__.py)
